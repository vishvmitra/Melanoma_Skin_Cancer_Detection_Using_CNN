# %% [markdown]
# ### **Melonama Cancer Detection Assignment using NN: **
#
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping

from tensorflow.keras.preprocessing.image import load_img

# %% [markdown]
# #### mount google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #### unzip the dataset

# %%
# !unzip "/content/gdrive/MyDrive/CNN_assignment.zip" > /dev/null

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
data_dir_train = pathlib.Path("/content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/")
data_dir_test = pathlib.Path('/content/Skin cancer ISIC The International Skin Imaging Collaboration/Test/')

# %%
#Train Image count
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)

#Test Image count
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# #### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=32,image_size=(180,180),subset="training",
                                                                    label_mode='categorical',seed=123, validation_split=0.2)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=32,image_size=(180,180),subset="validation",
                                                                    label_mode='categorical',seed=123, validation_split=0.2)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %% [markdown]
# #### List out all the classes of skin cancer and store them in a list.
# #### You can find the class names in the class_names attribute on these datasets.
# #### These correspond to the directory names in alphabetical order.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

#Visualize one instance of all the class present in the dataset.
#Dictionary to store the path of image as per the class
files_path_dict = {}

for c in class_names:
    files_path_dict[c] = list(map(lambda x:str(data_dir_train)+'/'+c+'/'+x,os.listdir(str(data_dir_train)+'/'+c)))
    
#Visualize image 
plt.figure(figsize=(15,15))
index = 0
for c in class_names:
    path_list = files_path_dict[c][:1]
    index += 1
    plt.subplot(3,3,index)
    plt.imshow(load_img(path_list[0],target_size=(180,180)))
    plt.title(c)
    plt.axis("off")

# %%
def class_distribution_count(directory):
    
    #count number of image in each classes
    count= []
    for path in pathlib.Path(directory).iterdir():
        if path.is_dir():
            count.append(len([name for name in os.listdir(path)
                               if os.path.isfile(os.path.join(path, name))]))
    
    #name of the classes
    sub_directory = [name for name in os.listdir(directory)
                    if os.path.isdir(os.path.join(directory, name))]
    
    #return dataframe with image count and class.
    return pd.DataFrame(list(zip(sub_directory,count)),columns =['Class', 'No. of Image'])

df = class_distribution_count(data_dir_train)
df
# Out:
#                         Class  No. of Image
# 0        basal cell carcinoma           376
# 1                       nevus           357
# 2              dermatofibroma            95
# 3     squamous cell carcinoma           181
# 4                    melanoma           438
# 5  pigmented benign keratosis           462
# 6        seborrheic keratosis            77
# 7             vascular lesion           139
# 8           actinic keratosis           114

# %%
#Visualize the Number of image in each class.
import seaborn as sns
plt.figure(figsize=(20, 10))
sns.barplot(x="Class", y="No. of Image", data=df,
            label="Class")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.
#
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
#CNN Model Architecture

#Sequential allows you to create models layer-by-layer  
model = Sequential()

model.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer

#First Convulation layer
model.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Second Convulation Layer
model.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Third Convulation Layer
model.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 50% Fraction of the input units to drop.
model.add(layers.Dropout(0.5))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model.add(layers.Flatten())

#Dense Layer
model.add(layers.Dense(128,activation='relu'))

#Dropout layer with 25% Fraction of the input units to drop.
model.add(layers.Dropout(0.25))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model.add(layers.Dense(len(class_names),activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  dropout (Dropout)           (None, 20, 20, 128)       0
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 128)               6553728
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 6,648,137
# Trainable params: 6,648,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
# vizualizing the model 
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# #### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
#Compile the Model

#Adam optimization: is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments.
#categorical_crossentropy: Used as a loss function for multi-class classification model where there are two or more output labels.

model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

#ModelCheckpoint callback is used in conjunction with training using model.fit() to save a model or weights (in a checkpoint file) at some interval,
#so the model or weights can be loaded later to continue the training from the state saved.
checkpoint = ModelCheckpoint("model.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)

#Stop training when a monitored metric has stopped improving.
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,mode="auto",verbose=1)

# %% [markdown]
# ### Train the model

# %%
# Train the model
epochs = 20
history = model.fit(train_ds, validation_data=val_ds, epochs=epochs,callbacks=[checkpoint,earlystop])
# Out:
# Epoch 1/20
# 56/56 [==============================] - ETA: 0s - loss: 2.1208 - accuracy: 0.2093
# Epoch 1: val_accuracy improved from -inf to 0.27964, saving model to model.h5
# 56/56 [==============================] - 127s 2s/step - loss: 2.1208 - accuracy: 0.2093 - val_loss: 1.9559 - val_accuracy: 0.2796
# Epoch 2/20
# 56/56 [==============================] - ETA: 0s - loss: 1.8425 - accuracy: 0.3326
# Epoch 2: val_accuracy did not improve from 0.27964
# 56/56 [==============================] - 106s 2s/step - loss: 1.8425 - accuracy: 0.3326 - val_loss: 1.9354 - val_accuracy: 0.2640
# Epoch 3/20
# 56/56 [==============================] - ETA: 0s - loss: 1.7117 - accuracy: 0.3728
# Epoch 3: val_accuracy improved from 0.27964 to 0.48546, saving model to model.h5
# 56/56 [==============================] - 106s 2s/step - loss: 1.7117 - accuracy: 0.3728 - val_loss: 1.5658 - val_accuracy: 0.4855
# Epoch 4/20
# 56/56 [==============================] - ETA: 0s - loss: 1.5454 - accuracy: 0.4408
# Epoch 4: val_accuracy improved from 0.48546 to 0.48770, saving model to model.h5
# 56/56 [==============================] - 106s 2s/step - loss: 1.5454 - accuracy: 0.4408 - val_loss: 1.4769 - val_accuracy: 0.4877
# Epoch 5/20
# 56/56 [==============================] - ETA: 0s - loss: 1.4995 - accuracy: 0.4710
# Epoch 5: val_accuracy improved from 0.48770 to 0.51678, saving model to model.h5
# 56/56 [==============================] - 105s 2s/step - loss: 1.4995 - accuracy: 0.4710 - val_loss: 1.3862 - val_accuracy: 0.5168
# Epoch 6/20
# 56/56 [==============================] - ETA: 0s - loss: 1.3657 - accuracy: 0.5167
# Epoch 6: val_accuracy improved from 0.51678 to 0.52125, saving model to model.h5
# 56/56 [==============================] - 107s 2s/step - loss: 1.3657 - accuracy: 0.5167 - val_loss: 1.4174 - val_accuracy: 0.5213
# Epoch 7/20
# 56/56 [==============================] - ETA: 0s - loss: 1.3135 - accuracy: 0.5469
# Epoch 7: val_accuracy did not improve from 0.52125
# 56/56 [==============================] - 105s 2s/step - loss: 1.3135 - accuracy: 0.5469 - val_loss: 1.3762 - val_accuracy: 0.5056
# Epoch 8/20
# 56/56 [==============================] - ETA: 0s - loss: 1.3109 - accuracy: 0.5480
# Epoch 8: val_accuracy did not improve from 0.52125
# 56/56 [==============================] - 105s 2s/step - loss: 1.3109 - accuracy: 0.5480 - val_loss: 1.4703 - val_accuracy: 0.4720
# Epoch 9/20
# 56/56 [==============================] - ETA: 0s - loss: 1.2265 - accuracy: 0.5580
# Epoch 9: val_accuracy improved from 0.52125 to 0.53915, saving model to model.h5
# 56/56 [==============================] - 105s 2s/step - loss: 1.2265 - accuracy: 0.5580 - val_loss: 1.3256 - val_accuracy: 0.5391
# Epoch 10/20
# 56/56 [==============================] - ETA: 0s - loss: 1.2234 - accuracy: 0.5636
# Epoch 10: val_accuracy did not improve from 0.53915
# 56/56 [==============================] - 105s 2s/step - loss: 1.2234 - accuracy: 0.5636 - val_loss: 1.3666 - val_accuracy: 0.5369
# Epoch 11/20
# 56/56 [==============================] - ETA: 0s - loss: 1.1546 - accuracy: 0.5898
# Epoch 11: val_accuracy did not improve from 0.53915
# 56/56 [==============================] - 109s 2s/step - loss: 1.1546 - accuracy: 0.5898 - val_loss: 1.3563 - val_accuracy: 0.5101
# Epoch 12/20
# 56/56 [==============================] - ETA: 0s - loss: 1.1052 - accuracy: 0.5988
# Epoch 12: val_accuracy improved from 0.53915 to 0.55034, saving model to model.h5
# 56/56 [==============================] - 105s 2s/step - loss: 1.1052 - accuracy: 0.5988 - val_loss: 1.3705 - val_accuracy: 0.5503
# Epoch 13/20
# 56/56 [==============================] - ETA: 0s - loss: 1.0829 - accuracy: 0.6038
# Epoch 13: val_accuracy did not improve from 0.55034
# 56/56 [==============================] - 105s 2s/step - loss: 1.0829 - accuracy: 0.6038 - val_loss: 1.6536 - val_accuracy: 0.4474
# Epoch 14/20
# 56/56 [==============================] - ETA: 0s - loss: 1.0890 - accuracy: 0.6144
# Epoch 14: val_accuracy did not improve from 0.55034
# 56/56 [==============================] - 104s 2s/step - loss: 1.0890 - accuracy: 0.6144 - val_loss: 1.4743 - val_accuracy: 0.5414
# Epoch 15/20
# 56/56 [==============================] - ETA: 0s - loss: 0.9926 - accuracy: 0.6406
# Epoch 15: val_accuracy did not improve from 0.55034
# 56/56 [==============================] - 104s 2s/step - loss: 0.9926 - accuracy: 0.6406 - val_loss: 1.4937 - val_accuracy: 0.5414
# Epoch 16/20
# 56/56 [==============================] - ETA: 0s - loss: 0.9410 - accuracy: 0.6451
# Epoch 16: val_accuracy did not improve from 0.55034
# 56/56 [==============================] - 105s 2s/step - loss: 0.9410 - accuracy: 0.6451 - val_loss: 1.4895 - val_accuracy: 0.5257
# Epoch 17/20
# 56/56 [==============================] - ETA: 0s - loss: 0.9130 - accuracy: 0.6607
# Epoch 17: val_accuracy improved from 0.55034 to 0.55705, saving model to model.h5
# 56/56 [==============================] - 105s 2s/step - loss: 0.9130 - accuracy: 0.6607 - val_loss: 1.4703 - val_accuracy: 0.5570
# Epoch 18/20
# 56/56 [==============================] - ETA: 0s - loss: 0.8664 - accuracy: 0.6758
# Epoch 18: val_accuracy did not improve from 0.55705
# 56/56 [==============================] - 105s 2s/step - loss: 0.8664 - accuracy: 0.6758 - val_loss: 1.4815 - val_accuracy: 0.5503
# Epoch 19/20
# 56/56 [==============================] - ETA: 0s - loss: 0.8136 - accuracy: 0.7087
# Epoch 19: val_accuracy did not improve from 0.55705
# 56/56 [==============================] - 105s 2s/step - loss: 0.8136 - accuracy: 0.7087 - val_loss: 1.5446 - val_accuracy: 0.5347
# Epoch 20/20
# 56/56 [==============================] - ETA: 0s - loss: 0.8296 - accuracy: 0.7048
# Epoch 20: val_accuracy did not improve from 0.55705
# 56/56 [==============================] - 104s 2s/step - loss: 0.8296 - accuracy: 0.7048 - val_loss: 1.6602 - val_accuracy: 0.5570

# %% [markdown]
# We got maximum validation accuracy of - 0.5570

# %% [markdown]
# ### Visualizing training results

# %%
# Plot the training curves

epochs_range = range(earlystop.stopped_epoch+1)

plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)

#Plot Model Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')

#Plot Model Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from glob import glob
Test_image_path = os.path.join(data_dir_test, class_names[1], '*')
Test_image = glob(Test_image_path)
Test_image = load_img(Test_image[-1],target_size=(180,180,3))
plt.imshow(Test_image)
plt.grid(False)

img = np.expand_dims(Test_image,axis=0)
pred = model.predict(img)
pred = np.argmax(pred)
pred_class = class_names[pred]
print("Actual Class "+ class_names[1] +'\n'+ "Predictive Class "+pred_class )
# Out:
# 1/1 [==============================] - 0s 169ms/step
# Actual Class basal cell carcinoma
# Predictive Class squamous cell carcinoma

# %% [markdown]
#  ### Findings for Model 1:
#  Best performance of the model is =>
#  loss: 0.8296 - accuracy: 0.7048 - val_loss: 1.6602 - val_accuracy: 0.5570
#
#  Even though the model performed decently well on the Training Set (Accuracy: 0.7048, Loss: 0.8296) it didn't perform on the validation dataset (Validation Accuracy: 0.5570, Validation_Loss: 1.6602).
#
#  This is a clear case of **UnderFitting**. As the data is not enough for the model across all the classes to train and understand the trends/patterns in the data. So, its performed bad on both training and validation dataset.

# %% [markdown]
# # Create Model 2 using Augmentor:
#
# We use a python package known as Augmentor (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
#install Augmentor
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Augmentor in /usr/local/lib/python3.7/dist-packages (0.2.10)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.1)

# %%
path_to_training_dataset="/content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500)  #Adding 500 samples per class to make sure that none of the classes are sparse
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FA469185650>: 100%|██████████| 500/500 [00:28<00:00, 17.26 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FA4690F5090>: 100%|██████████| 500/500 [00:28<00:00, 17.66 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FA472C37C10>: 100%|██████████| 500/500 [00:29<00:00, 17.22 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FA4690C8650>: 100%|██████████| 500/500 [01:46<00:00,  4.71 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=767x576 at 0x7FA469099190>: 100%|██████████| 500/500 [01:43<00:00,  4.83 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FA4690AB1D0>: 100%|██████████| 500/500 [00:21<00:00, 23.70 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FA463460910>: 100%|██████████| 500/500 [00:49<00:00, 10.19 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FA469432B10>: 100%|██████████| 500/500 [00:21<00:00, 23.80 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FA472B4F350>: 100%|██████████| 500/500 [00:20<00:00, 24.30 Samples/s]

# %%
#Count total number of image generated by Augmentor.
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %%
# train dataset 
train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train, batch_size=32,
                                                               image_size=(180,180), label_mode='categorical',
                                                               seed=123,subset="training",
                                                               validation_split=0.2)

#label_mode is categorial, the labels are a float32 tensor of shape (batch_size, num_classes),
#representing a one-hot encoding of the class index.
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %%
# validation dataset 
val_ds =tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=32,
                                                            image_size=(180,180), label_mode='categorical',
                                                            seed=123,subset="validation",
                                                            validation_split=0.2)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %%
#tf.data.experimental.AUTOTUNE defines appropriate number of processes that are free for working.

#`Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.

#`Dataset.prefetch()` overlaps data preprocessing and model execution while training.


AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#CNN Model Architecture

#Sequential allows you to create models layer-by-layer  
model = Sequential()

model.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer

#First Convulation layer
model.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Second Convulation Layer
model.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Third Convulation Layer
model.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 50% Fraction of the input units to drop.
model.add(layers.Dropout(0.5))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model.add(layers.Flatten())

#Dense Layer
model.add(layers.Dense(128,activation='relu'))

#Dropout layer with 25% Fraction of the input units to drop.
model.add(layers.Dropout(0.25))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model.add(layers.Dense(len(class_names),activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_3 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 20, 20, 128)       0
#
#  flatten_1 (Flatten)         (None, 51200)             0
#
#  dense_2 (Dense)             (None, 128)               6553728
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 6,648,137
# Trainable params: 6,648,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
# vizualizing the model 
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
#Compile the Model

#Adam optimization: is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments.
#categorical_crossentropy: Used as a loss function for multi-class classification model where there are two or more output labels.

model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

#ModelCheckpoint callback is used in conjunction with training using model.fit() to save a model or weights (in a checkpoint file) at some interval,
#so the model or weights can be loaded later to continue the training from the state saved.
checkpoint = ModelCheckpoint("model.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)

#Stop training when a monitored metric has stopped improving.
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,mode="auto",verbose=1)

# %%
# Train the model
epochs = 20
history = model.fit(train_ds, validation_data=val_ds, epochs=epochs,callbacks=[checkpoint,earlystop])
# Out:
# Epoch 1/20
# 169/169 [==============================] - ETA: 0s - loss: 1.9692 - accuracy: 0.2554
# Epoch 1: val_accuracy improved from -inf to 0.42910, saving model to model.h5
# 169/169 [==============================] - 370s 2s/step - loss: 1.9692 - accuracy: 0.2554 - val_loss: 1.5241 - val_accuracy: 0.4291
# Epoch 2/20
# 169/169 [==============================] - ETA: 0s - loss: 1.5235 - accuracy: 0.4254
# Epoch 2: val_accuracy did not improve from 0.42910
# 169/169 [==============================] - 319s 2s/step - loss: 1.5235 - accuracy: 0.4254 - val_loss: 1.4945 - val_accuracy: 0.4269
# Epoch 3/20
# 169/169 [==============================] - ETA: 0s - loss: 1.3594 - accuracy: 0.4937
# Epoch 3: val_accuracy improved from 0.42910 to 0.48627, saving model to model.h5
# 169/169 [==============================] - 324s 2s/step - loss: 1.3594 - accuracy: 0.4937 - val_loss: 1.3917 - val_accuracy: 0.4863
# Epoch 4/20
# 169/169 [==============================] - ETA: 0s - loss: 1.2361 - accuracy: 0.5378
# Epoch 4: val_accuracy improved from 0.48627 to 0.55902, saving model to model.h5
# 169/169 [==============================] - 321s 2s/step - loss: 1.2361 - accuracy: 0.5378 - val_loss: 1.2031 - val_accuracy: 0.5590
# Epoch 5/20
# 169/169 [==============================] - ETA: 0s - loss: 1.1303 - accuracy: 0.5740
# Epoch 5: val_accuracy improved from 0.55902 to 0.57238, saving model to model.h5
# 169/169 [==============================] - 338s 2s/step - loss: 1.1303 - accuracy: 0.5740 - val_loss: 1.1784 - val_accuracy: 0.5724
# Epoch 6/20
# 169/169 [==============================] - ETA: 0s - loss: 1.0248 - accuracy: 0.6193
# Epoch 6: val_accuracy improved from 0.57238 to 0.63920, saving model to model.h5
# 169/169 [==============================] - 321s 2s/step - loss: 1.0248 - accuracy: 0.6193 - val_loss: 0.9947 - val_accuracy: 0.6392
# Epoch 7/20
# 169/169 [==============================] - ETA: 0s - loss: 0.9202 - accuracy: 0.6639
# Epoch 7: val_accuracy did not improve from 0.63920
# 169/169 [==============================] - 320s 2s/step - loss: 0.9202 - accuracy: 0.6639 - val_loss: 1.1593 - val_accuracy: 0.6102
# Epoch 8/20
# 169/169 [==============================] - ETA: 0s - loss: 0.8774 - accuracy: 0.6775
# Epoch 8: val_accuracy improved from 0.63920 to 0.71418, saving model to model.h5
# 169/169 [==============================] - 320s 2s/step - loss: 0.8774 - accuracy: 0.6775 - val_loss: 0.8627 - val_accuracy: 0.7142
# Epoch 9/20
# 169/169 [==============================] - ETA: 0s - loss: 0.8016 - accuracy: 0.6968
# Epoch 9: val_accuracy did not improve from 0.71418
# 169/169 [==============================] - 320s 2s/step - loss: 0.8016 - accuracy: 0.6968 - val_loss: 0.9288 - val_accuracy: 0.6971
# Epoch 10/20
# 169/169 [==============================] - ETA: 0s - loss: 0.7172 - accuracy: 0.7383
# Epoch 10: val_accuracy did not improve from 0.71418
# 169/169 [==============================] - 318s 2s/step - loss: 0.7172 - accuracy: 0.7383 - val_loss: 0.9331 - val_accuracy: 0.6956
# Epoch 11/20
# 169/169 [==============================] - ETA: 0s - loss: 0.6887 - accuracy: 0.7446
# Epoch 11: val_accuracy did not improve from 0.71418
# 169/169 [==============================] - 316s 2s/step - loss: 0.6887 - accuracy: 0.7446 - val_loss: 0.8556 - val_accuracy: 0.7016
# Epoch 12/20
# 169/169 [==============================] - ETA: 0s - loss: 0.6599 - accuracy: 0.7522
# Epoch 12: val_accuracy improved from 0.71418 to 0.77283, saving model to model.h5
# 169/169 [==============================] - 317s 2s/step - loss: 0.6599 - accuracy: 0.7522 - val_loss: 0.7412 - val_accuracy: 0.7728
# Epoch 13/20
# 169/169 [==============================] - ETA: 0s - loss: 0.6005 - accuracy: 0.7669
# Epoch 13: val_accuracy improved from 0.77283 to 0.78248, saving model to model.h5
# 169/169 [==============================] - 316s 2s/step - loss: 0.6005 - accuracy: 0.7669 - val_loss: 0.6677 - val_accuracy: 0.7825
# Epoch 14/20
# 169/169 [==============================] - ETA: 0s - loss: 0.5467 - accuracy: 0.7908
# Epoch 14: val_accuracy improved from 0.78248 to 0.80252, saving model to model.h5
# 169/169 [==============================] - 316s 2s/step - loss: 0.5467 - accuracy: 0.7908 - val_loss: 0.6694 - val_accuracy: 0.8025
# Epoch 15/20
# 169/169 [==============================] - ETA: 0s - loss: 0.5208 - accuracy: 0.8069
# Epoch 15: val_accuracy did not improve from 0.80252
# 169/169 [==============================] - 316s 2s/step - loss: 0.5208 - accuracy: 0.8069 - val_loss: 1.0959 - val_accuracy: 0.6615
# Epoch 16/20
# 169/169 [==============================] - ETA: 0s - loss: 0.5235 - accuracy: 0.8003
# Epoch 16: val_accuracy did not improve from 0.80252
# 169/169 [==============================] - 315s 2s/step - loss: 0.5235 - accuracy: 0.8003 - val_loss: 0.6319 - val_accuracy: 0.7936
# Epoch 17/20
# 169/169 [==============================] - ETA: 0s - loss: 0.4772 - accuracy: 0.8138
# Epoch 17: val_accuracy did not improve from 0.80252
# 169/169 [==============================] - 316s 2s/step - loss: 0.4772 - accuracy: 0.8138 - val_loss: 0.7445 - val_accuracy: 0.7617
# Epoch 18/20
# 169/169 [==============================] - ETA: 0s - loss: 0.4607 - accuracy: 0.8221
# Epoch 18: val_accuracy did not improve from 0.80252
# 169/169 [==============================] - 317s 2s/step - loss: 0.4607 - accuracy: 0.8221 - val_loss: 0.7797 - val_accuracy: 0.7446
# Epoch 19/20
# 169/169 [==============================] - ETA: 0s - loss: 0.4632 - accuracy: 0.8247
# Epoch 19: val_accuracy did not improve from 0.80252
# 169/169 [==============================] - 317s 2s/step - loss: 0.4632 - accuracy: 0.8247 - val_loss: 0.6833 - val_accuracy: 0.7877
# Epoch 19: early stopping

# %% [markdown]
# The new Validation accuracy after running augmenter is  0.80252

# %%
# Plot the training curves

epochs_range = range(earlystop.stopped_epoch+1)

plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)

#Plot Model Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')

#Plot Model Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from glob import glob
Test_image_path = os.path.join(data_dir_test, class_names[1], '*')
Test_image = glob(Test_image_path)
Test_image = load_img(Test_image[-1],target_size=(180,180,3))
plt.imshow(Test_image)
plt.grid(False)

img = np.expand_dims(Test_image,axis=0)
pred = model.predict(img)
pred = np.argmax(pred)
pred_class = class_names[pred]
print("Actual Class "+ class_names[1] +'\n'+ "Predictive Class "+pred_class )
# Out:
# 1/1 [==============================] - 0s 40ms/step
# Actual Class basal cell carcinoma
# Predictive Class actinic keratosis

# %% [markdown]
# ## Findings:
#
# loss: 0.4632 - accuracy: 0.8247 - val_loss: 0.6833 - val_accuracy: 0.7877
#
# The Model 2 using the Augmentor, performed decently well on both training and validation dataset. The accuracy for both training and validation datasets were similar -
# Training set Accuracy : 0.8247
# Validation Set Accuracy: 0.7877
#
# This means the model is well trained with **no case** of underfitting or overfitting.
